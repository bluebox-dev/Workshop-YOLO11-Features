# %% [markdown]
# # Setup YOLO11
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/requirements.txt) and check software and hardware.

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()

# %% [markdown]
# # 1. Predict ( Test Setup YOLO11-segment )
#
# YOLOv11m-seg may be used directly in the Command Line Interface (CLI) with a `yolo` command for segmentation tasks and modes.
# It accepts additional arguments such as `imgsz=640` for image size and `conf=0.25` for confidence threshold.

# %%
# Run inference on an image with YOLOv11m-segment
# !yolo predict model=yolo11m-seg.pt source='https://ultralytics.com/images/zidane.jpg'  imgsz=640 conf=0.25

# %% [markdown]
# # 2. Add Zip Data Export YOLO11-segment for Roboflow

# %%
import zipfile
from google.colab import files

# %cd /content
uploaded = files.upload()
for filename in uploaded.keys():
  pass

zip_ref = zipfile.ZipFile(filename, 'r')
zip_ref.extractall("/content/")

# %% [markdown]
# # 3. Train Data Roboflow

# %%
# Validate YOLOv11m-Segment
# !yolo train model=yolo11m-seg.pt data=data.yaml epochs=100 imgsz=640

# %% [markdown]
# # 4. Test Model Training

# %%
# !yolo detect predict model=/content/runs/segment/train/weights/best.pt conf=0.8 imgsz=640 source='/content/test/images/'

# %% [markdown]
# # 5. Test Video for Model Ai

# %%
# !yolo detect predict model=/content/runs/detect/train/weights/best.pt  conf=0.8 imgsz=640 source='/content/drive/MyDrive/1A/DataTestENV2.mp4'
